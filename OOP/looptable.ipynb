# %%
num=int(input("Enter the table :"))
f_num=int(input("Enter the first no:"))
l_num=int(input("Enter the last no:"))

for i in range(f_num,l_num):
    print (num,"*",i ,"=" ,num*i)
# Out:
# 40 * 1 = 40
# 40 * 2 = 80
# 40 * 3 = 120
# 40 * 4 = 160
# 40 * 5 = 200
# 40 * 6 = 240
# 40 * 7 = 280
# 40 * 8 = 320
# 40 * 9 = 360
# 40 * 10 = 400
# 40 * 11 = 440
