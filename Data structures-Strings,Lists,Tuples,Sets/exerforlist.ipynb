# %%
# Access the third element of a list
# List Length: Print the total number of items
# Check if the list is empty

colour=["Red","Green","Blue","Saffron","White"]
print(colour[3])
print(len(colour))
colour1=[]
if not list:
    print("empty list")
else:
    print("not empty")

#colour = ["red", "green", "blue"]

colour[1]=200
print(colour)

colour.append("600")
print(colour)
# Out:
# Saffron
# 5
# not empty
# ['Red', 200, 'Blue', 'Saffron', 'White']
# ['Red', 200, 'Blue', 'Saffron', 'White', '600']
