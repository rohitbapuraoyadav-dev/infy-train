# %%
class Employee():
    hospital="Kaiser"

    def __init__(self,name,role):
        self.name=name
        self.role=role

emp1=Employee("jhon","Doctor")
emp2=Employee("Dove","Nurse")
Employee.hospital="KP Health"

print(emp1.hospital,emp2.hospital)
# Out:
# KP Health KP Health

# %%
#exercise 1

str1="WelcometotheWorld"
print(str1[0])
print(str1[-1])
print(str1[len(str1)//2])
result=str1[0]+(str1[len(str1)//2])+str1[-1]
print (result)
# Out:
# W
# d
# o
# Wod

# %%
str1="HelloJamesHolland"
print(str1[len(str1)//2])
m_index=len(str1)//2
print("Middle index",m_index)
print("Middle character",str1[m_index])
print("Middle 3 alpha :",str1[m_index-1 : m_index+2])
# Out:
# e
# Middle index 8
# Middle character e
# Middle 3 alpha : mes

# %%
s1="Hello"
s2="WorldU"
s1=len(s1//2)

result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 s1="Hello"
#       2 s2="WorldU"
# ----> 3 s1=len(s1//2)
#
# TypeError: unsupported operand type(s) for //: 'str' and 'int'
