# %%
#create tuple
tuple01=()
tuple02=("Hello","Welcome","Hi") #values in tuples
print(tuple02)

#tuple02.insert(1,"Bye")# no insert option-immutable,similarly no spprnd
#tuple([2])="Bye" # also no replacement allowed

print(tuple02[0])
print(tuple02[-1])

for t in tuple02:
    print(t)
print(tuple02[1:3])

tuple03=(12,34,56,67,89,90) #no sequencing done here
print(tuple03)

print(tuple03 * 2)
print(tuple03) #original tuple will remain the same
# Out:
# ('Hello', 'Welcome', 'Hi')
# Hello
# Hi
# Hello
# Welcome
# Hi
# ('Welcome', 'Hi')
# (12, 34, 56, 67, 89, 90)
# (12, 34, 56, 67, 89, 90, 12, 34, 56, 67, 89, 90)
# (12, 34, 56, 67, 89, 90)

# %%
#exercise

fruits = ("apple", "banana", "cherry", "date")
print(fruits[0])
print(fruits[-1])
print(len(fruits))

t=(50,)
print(t)
type(t)

a = (1, 2)
b = (3, 4)
c = (5, 6)
rt=a+b+c
print(rt)
# Out:
# apple
# date
# 4
# (50,)
# (1, 2, 3, 4, 5, 6)

# %%
#ex-11

person=("Alice",30,"Engineer","Pune")
name ,age ,job ,city = person

print("Name ",name)
print("Job ",job)
print("City ",city)
print("age ",age)

def Showvalues(name, age, job, city):
    return name, age, job, city

name, age, job, city = Showvalues("Alice", 30, "Engineer", "Pune")

print("Name:", name)
print("Job:", job)
print("City:", city)
print("Age:", age)
# Out:
# Name  Alice
# Job  Engineer
# City  Pune
# age  30
# Name: Alice
# Job: Engineer
# City: Pune
# Age: 30

# %%
my_list = [10, 20, 30, 40, 50]
my_tuple=tuple(my_list)
print(my_tuple)
type(my_tuple)

#8

chars = ('a', 'b', 'c')
result="".join(chars)
print(result)
# Out:
# (10, 20, 30, 40, 50)
# abc
