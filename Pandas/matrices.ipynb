# %%
import numpy as np

A = np.array([[1,2,3],
              [0,1,2],
              [3,2,1]])

det = np.linalg.det(A)

print(det)

det = np.linalg.det(A)

print(np.isclose(det, 0))
print(round(det))
# Out:
# 1.7763568394002396e-15
# True
# 0
