# %% [markdown]
# Working with Panda Series

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.2.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

series=pd.Series([12,23,34,45,56,67])
print(series)

# Display the result
print('Resultant Empty Series:\n',s)

#retrive the last 3 values

print(series[:5])
# Out:
# 0    12
# 1    23
# 2    34
# 3    45
# 4    56
# 5    67
# dtype: int64
# Resultant Empty Series:
#  0    a
# 1    b
# 2    c
# 3    d
# dtype: object
# 0    12
# 1    23
# 2    34
# 3    45
# 4    56
# dtype: int64

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
print("Output:\n",s)
# Out:
# Output:
#  100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data,index=[100,101,102,103])
print("Output:\n",s)
# Out:
# Output:
#  100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data,index=['b','c','x','a'])
print(s)
# Out:
# b    1.0
# c    2.0
# x    NaN
# a    0.0
# dtype: float64

# %%
#import the pandas library and aliasing as pd
import pandas as pd
import numpy as np
s = pd.Series(5, index=[0, 1, 2, 3])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
#Access Data from Panda Series

# %%
import pandas as pd
import numpy as np

data = np.array(['a', 'b', 'c', 'd'])
s = pd.Series(data)

# Display the Original series
print('Original Series:',s, sep='\n')

# Slice the range of values
result = s[1:3]

# Display the output
print('Values after slicing the Series:', result, sep='\n')

result = s[0:4:2]
print(result)
# Out:
# Original Series:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object
# Values after slicing the Series:
# 1    b
# 2    c
# dtype: object
# 0    a
# 2    c
# dtype: object

# %% [markdown]
# Data modification in panda series

# %%
import pandas as pd
s = pd.Series([1,2,3,4,5])

# Display the original series 
print("Original Series:\n",s)

# Modify the values of first two elements
s[:2] = [100, 200]

print("Series after modifying the first two elements:",s)
# Out:
# Original Series:
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# Series after modifying the first two elements: 0    100
# 1    200
# 2      3
# 3      4
# 4      5
# dtype: int64

# %%
#Panda Series Attributes

series = pd.Series([1,2,3,4,5])

print("Empty:",series.empty)
print("Axes:",series.axes)
print("First Value:",series.first)
#print("List conversion:",series.list(0:3))
print(series.flags)
print("No of values:",series.size)
print("No of demension:",series.ndim)
print("No of keys:",series.keys)
print("No of shape:",series.shape)
# Out:
# Empty: False
# Axes: [RangeIndex(start=0, stop=5, step=1)]
# First Value: <bound method NDFrame.first of 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64>
# <Flags(allows_duplicate_labels=True)>
# No of values: 5
# No of demension: 1
# No of keys: <bound method Series.keys of 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64>
# No of shape: (5,)

# %% [markdown]
# Arthimetic Operations with Series

# %%
print("Multiplication:",series*2)
print("Addition",series + 2)
print("Division:",series/2)
print("Floor Division:",series//2)
print("Exponential:",series**2)
# Out:
# Multiplication: 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# Addition 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64
# Division: 0    0.5
# 1    1.0
# 2    1.5
# 3    2.0
# 4    2.5
# dtype: float64
# Floor Division: 0    0
# 1    1
# 2    1
# 3    2
# 4    2
# dtype: int64
# Exponential: 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %% [markdown]
# utilizing a dictionary, we can have an index when creating a series. The first value (keys) are the index.

# %%
data_dictionary = {'Player 1': 30, 'Player 2': 25, 'Player 3': 15, 'Player 4': 10, 'Player 5': 20}
player_points_3 = pd.Series(data_dictionary)
print(player_points_3)

#Descritptive Statistics 
print("Mean:",player_points_3.mean())
print("median:",player_points_3.median())
print("mode:",player_points_3.mode())
print("SD:",player_points_3.std())
print("sum:",player_points_3.sum())
print("min:",player_points_3.min())
# Out:
# Player 1    30
# Player 2    25
# Player 3    15
# Player 4    10
# Player 5    20
# dtype: int64
# Mean: 20.0
# median: 20.0
# mode: 0    10
# 1    15
# 2    20
# 3    25
# 4    30
# dtype: int64
# SD: 7.905694150420948
# sum: 100
# min: 10

# %%
#null values

null_series = pd.Series([25, 10, 5, np.nan, 8, 41, np.nan])
null_series.isna()

null_series_removed=null_series.dropna() #delete
print(null_series_removed)

null_series_filled=null_series.fillna(0) #replace by 0
print(null_series_filled)

fill= null_series.fillna(null_series.median()) #replace by median
print(fill)
# Out:
# 0    25.0
# 1    10.0
# 2     5.0
# 4     8.0
# 5    41.0
# dtype: float64
# 0    25.0
# 1    10.0
# 2     5.0
# 3     0.0
# 4     8.0
# 5    41.0
# 6     0.0
# dtype: float64
# 0    25.0
# 1    10.0
# 2     5.0
# 3    10.0
# 4     8.0
# 5    41.0
# 6    10.0
# dtype: float64

# %%
import pandas as pd

series = pd.Series([1,2,3,4,5])

series.to_csv("file1.csv", index=False, header=["Numbers"])
