# %%
# Hosuing data set 

import pandas as pd

df= pd.read_csv("houseprice-dirty.csv")
df["total_area"] = df["LotArea"] + df["TotalBsmtSF"] + df["GrLivArea"] + df["GarageArea"] + df["WoodDeckSF"] + df["OpenPorchSF"] + df["EnclosedPorch"] + df["3SsnPorch"] + df["ScreenPorch"] + df["PoolArea"]
selected_columns = ["Id","Utilities","Neighborhood","BldgType","YearBuilt","YrSold","total_area","SalePrice"]
