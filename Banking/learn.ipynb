# %%
! cat data_files/CustomerDetails.dat
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
open("CustomerDetails.dat")
# Out:
# <_io.TextIOWrapper name='CustomerDetails.dat' mode='r' encoding='cp1252'>

# %%
file=open("CustomerDetails.dat")

# %%
file
# Out:
# <_io.TextIOWrapper name='CustomerDetails.dat' mode='r' encoding='cp1252'>

# %%
file.mode
# Out:
# 'r'

# %%
file.closed
# Out:
# False
